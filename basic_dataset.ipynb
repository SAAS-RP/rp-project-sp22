# %% [markdown]
# Dataset: https://www.kaggle.com/mylesoneill/classic-literature-in-ascii/activity
# This dataset contains complete written works of literature which are stored as text files.
#
# The purpose of this file is to parse these works and store them in a usable form, such as a pandas DataFrame.
#
# #### Imports

# %%
import pandas as pd
import numpy as np
import os
import collections
import nltk
from IPython.display import display

# %% [markdown]
# Retrieving each book file from its respective directory, then extracting its contents.

# %%
#setting up directories
cur_path = os.getcwd()
arch =  cur_path + "/archive"
auths = arch + "/AUTHORS/AUTHORS"
fict = arch + "/FICTION/FICTION"
nonfict = arch + "/NONFICTION/NONFICTION"

works = collections.defaultdict()
intro_str = "ETEXTS*Ver.04.29.93*END*"
#extracting works by author
for auth in os.listdir(auths):
    if auth == '.DS_Store':
        continue
    auth_dir = auths + '/' + auth
    os.chdir(auth_dir)
    for book in os.listdir(auth_dir):
        b_file = open(book, mode='r', encoding='cp1252')
        content = b_file.read()
        if intro_str in content:
            start_ind = content.index(intro_str)
            content = content[(start_ind+len(intro_str)):]
        works[book] = content

#adding fiction works
os.chdir(fict)
for book in os.listdir(fict):
    if book == '.DS_Store':
        continue
    b_file = open(book, mode='r', encoding='cp1252')
    content = b_file.read()
    if intro_str in content:
        start_ind = content.index(intro_str)
        content = content[(start_ind+len(intro_str)):]
    works[book] = content

#adding nonfiction works
os.chdir(nonfict)
for book in os.listdir(nonfict):
    if book == '.DS_Store':
        continue
    b_file = open(book, mode='r', encoding='cp1252')
    content = b_file.read()
    if intro_str in content:
        start_ind = content.index(intro_str)
        content = content[(start_ind+len(intro_str)):]
    works[book] = content

# %% [markdown]
# Creating a dictionary storing book titles, using the year those books were written (which is roughly parsed from the initial few words of the text) as a key.

# %%
books_and_years = collections.defaultdict()
for book in works.keys():
    words_in_book = nltk.tokenize.word_tokenize(works[book])
    first_nums_in_book = [int(w) for w in words_in_book[:250] if w.isnumeric()]
    year = 0
    if len(first_nums_in_book) > 0:
        if 2022 > max(first_nums_in_book) > 1000:
            year = min([x for x in first_nums_in_book if x > 1000])
        elif 50 <= max(first_nums_in_book) < 1000:
            year = max([x for x in first_nums_in_book])
        else:
            continue
        if books_and_years.get(year) is None:
            books_and_years[year] = [book]
        else:
            books_and_years[year] = books_and_years[year] + [book]

# %% [markdown]
# Tabulating words by year (extracting year by tokenizing novels and parsing from initial few words)

# %%
years_with_words = collections.defaultdict()
years_with_sentences = collections.defaultdict()
for year in books_and_years.keys():
    unique_words_in_year = []
    unique_sents_in_year = []
    for book in books_and_years[year]:
        words_in_book = nltk.tokenize.word_tokenize(works[book])
        sentences_in_book = [s.replace('\n', ' ') for s in nltk.tokenize.sent_tokenize(works[book])]
        unique_words_in_year += words_in_book
        unique_sents_in_year += sentences_in_book
        unique_words_in_year = list(set(unique_words_in_year))
        unique_sents_in_year = list(set(unique_sents_in_year))
    years_with_words[year] = unique_words_in_year
    years_with_sentences[year] = unique_sents_in_year

# %% [markdown]
# Converting dictionary of words to pandas DataFrame.

# %%
words_with_years = pd.DataFrame.from_dict(years_with_words, orient='index')
display(words_with_years)
# Out:
#          0          1         2            3           4             5      \
# 1838   shining       pale      felt           --   expansion          sole
# 1895      pale       felt        --       feudal    tyrannic          dint
# 1850      pale       felt    petted           --      feudal       Dashers
# 1837    slopes  vermiform      pale         felt          --  warm-blooded
# 1831  dripping       pale    'Neath       rustle         Let      Wrapping
# ...        ...        ...       ...          ...         ...           ...
# 170     Seeing      sects      cava  Hippocratic       Alone   distributed
# 1713    Seeing       mite   pursuit        sects        felt            --
# 1955    lusted       pale      felt           --         654      scholars
# 101       pale       felt  scholars    admitting  courageous         raise
# 1660      felt         --       654    admitting      stoics  Opposition.-
#
#                  6           7              8              9      ... 38586  \
# 1838               Let   animation    distributed       sidewalk  ...  None
# 1895          unlikely       exult        trained           Foul  ...  None
# 1850               orb  half-fancy       dilation   unhappiness-  ...  None
# 1837         admitting    slowness  entomologists     courageous  ...  None
# 1831           Stygian        this          Earth            hid  ...  None
# ...                ...         ...            ...            ...  ...   ...
# 170          expansion  definitely            Let        regains  ...  None
# 1713              sole  imposition            Let       ensnared  ...  None
# 1955           unmanly       raise     friendship        sadness  ...  None
# 101         friendship     sadness        trained  deliberations  ...  None
# 1660  Contradictions.-       raise     friendship        sadness  ...  None
#
#      38587 38588 38589 38590 38591 38592 38593 38594 38595
# 1838  None  None  None  None  None  None  None  None  None
# 1895  None  None  None  None  None  None  None  None  None
# 1850  None  None  None  None  None  None  None  None  None
# 1837  None  None  None  None  None  None  None  None  None
# 1831  None  None  None  None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 170   None  None  None  None  None  None  None  None  None
# 1713  None  None  None  None  None  None  None  None  None
# 1955  None  None  None  None  None  None  None  None  None
# 101   None  None  None  None  None  None  None  None  None
# 1660  None  None  None  None  None  None  None  None  None
#
# [189 rows x 38596 columns]

# %% [markdown]
# Serializing DataFrame to file 'words.pkl' for use in later files.

# %%
os.chdir(cur_path)
words_with_years.to_pickle('./words.pkl')

# %% [markdown]
# Serializing books and years dictionary (to dataframe first) for future use.

# %%
years_and_books = pd.DataFrame.from_dict(books_and_years, orient='index')
display(years_and_books)
# Out:
#                                  0                        1   \
# 1838             poe-ligeia-452.txt  poe-predicament-421.txt
# 1895                poe-pit-110.txt              the_pit.txt
# 1850            poe-morning-559.txt    poe-landscape-689.txt
# 1837            poe-silence-656.txt       poe-sonnet-661.txt
# 1831            poe-sleeper-703.txt      poe-israfel-448.txt
# ...                             ...                      ...
# 170                   faculties.txt                     None
# 1713         berkeley-three-745.txt                     None
# 1955  augustine-confessions-276.txt                     None
# 101    epictetus-discourses-568.txt                     None
# 1660         pascal-pensees-569.txt                     None
#
#                           2                            3   \
# 1838  hawthorne-lady-472.txt      hawthorne-peter-479.txt
# 1895                cask.txt                 telltale.txt
# 1850    poe-thousand-708.txt   poe-metzengerstein-557.txt
# 1837      poe-bridal-431.txt  hawthorne-prophetic-476.txt
# 1831        poe-city-673.txt               poe-to-715.txt
# ...                      ...                          ...
# 170                     None                         None
# 1713                    None                         None
# 1955                    None                         None
# 101                     None                         None
# 1660                    None                         None
#
#                         4                   5                      6   \
# 1838                  None                None                   None
# 1895          b-p_plan.txt         chilc10.txt  scott-ivanhoe-159.txt
# 1850    poe-sphinx-705.txt   poe-three-710.txt        poe-man-691.txt
# 1837  hawthorne-dr-468.txt  origin_species.txt                   None
# 1831    poe-valley-709.txt  poe-lenore-451.txt                   None
# ...                    ...                 ...                    ...
# 170                   None                None                   None
# 1713                  None                None                   None
# 1955                  None                None                   None
# 101                   None                None                   None
# 1660                  None                None                   None
#
#                    7                 8                9   ...  \
# 1838             None              None             None  ...
# 1895     redbadge.txt              None             None  ...
# 1850  poe-bon-430.txt  poe-some-657.txt  poe-man-690.txt  ...
# 1837             None              None             None  ...
# 1831             None              None             None  ...
# ...               ...               ...              ...  ...
# 170              None              None             None  ...
# 1713             None              None             None  ...
# 1955             None              None             None  ...
# 101              None              None             None  ...
# 1660             None              None             None  ...
#
#                     43                     44                45  \
# 1838              None                   None              None
# 1895              None                   None              None
# 1850  poe-thou-416.txt  poe-elizabeth-438.txt  poe-loss-455.txt
# 1837              None                   None              None
# 1831              None                   None              None
# ...                ...                    ...               ...
# 170               None                   None              None
# 1713              None                   None              None
# 1955              None                   None              None
# 101               None                   None              None
# 1660              None                   None              None
#
#                         46                47             48  \
# 1838                  None              None           None
# 1895                  None              None           None
# 1850  poe-literary-454.txt  poe-four-443.txt  poe-x-726.txt
# 1837                  None              None           None
# 1831                  None              None           None
# ...                    ...               ...            ...
# 170                   None              None           None
# 1713                  None              None           None
# 1955                  None              None           None
# 101                   None              None           None
# 1660                  None              None           None
#
#                             49                       50  \
# 1838                      None                     None
# 1895                      None                     None
# 1850  hawthorne-scarlet-63.txt  hawthorne-great-466.txt
# 1837                      None                     None
# 1831                      None                     None
# ...                        ...                      ...
# 170                       None                     None
# 1713                      None                     None
# 1955                      None                     None
# 101                       None                     None
# 1660                      None                     None
#
#                           51                      52
# 1838                    None                    None
# 1895                    None                    None
# 1850  hawthorne-snow-478.txt  burton-arabian-363.txt
# 1837                    None                    None
# 1831                    None                    None
# ...                      ...                     ...
# 170                     None                    None
# 1713                    None                    None
# 1955                    None                    None
# 101                     None                    None
# 1660                    None                    None
#
# [189 rows x 53 columns]

# %% [markdown]
# Serializing years and books dataframe.

# %%
years_and_books.to_pickle('./books.pkl')

# %% [markdown]
# Serializing years and sentences dataframe.

# %%
sentences_with_years = pd.DataFrame.from_dict(years_with_sentences, orient='index')
display(sentences_with_years)
sentences_with_years.to_pickle('./sentences.pkl')
# Out:
#                                                   0      \
# 1838                       "Turn him out of the house!"
# 1895          The youth leaned heavily upon his friend.
# 1850  She answered: "Allah Almighty vouchsafe to the...
# 1837  As soon as this occurred, the bees ceased to e...
# 1831  Oh, may her sleep       As it is lasting, so b...
# ...                                                 ...
# 170   The fact, therefore, that Erasistratus, in reg...
# 1713  Though indeed I deny they have an existence di...
# 1955  Have pity,  O Lord God, lest those who pass by...
# 101   have you anything better or greater to see tha...
# 1660                                         12-17; 66.
#
#                                                   1      \
# 1838      --shall this Conqueror be not once conquered?
# 1895                                     -- here, here!
# 1850  Now it was this latter peculiarity in his disp...
# 1837  Insects often resemble for the sake of protect...
# 1831  Sure thou art come O'er far-off seas,       A ...
# ...                                                 ...
# 170   For, if they do rebound, how then do they pass...
# 1713                       So far you are in the right.
# 1955                           Why are they not  happy?
# 101   I would willingly take a voyage for this purpo...
# 1660                                               635.
#
#                                                   2      \
# 1838  And in this expectation I was not at all decei...
# 1895                      The man screamed: "Let go me!
# 1850  It is, indeed, the instinct given to man by Go...
# 1837  Modifications in hard parts and in external pa...
# 1831                Heaven have her in its sacred keep!
# ...                                                 ...
# 170   Now, since the three faculties of Nature have ...
# 1713  In short, by whatever method you distinguish <...
# 1955                                    [633]       37.
# 101   And that you may not think that I show you the...
# 1660  What mysteries has he taught, even according t...
#
#                                                   3      \
# 1838  Amazement now struggled in my bosom with the p...
# 1895  Prince  John  coloured  as  he  put  the quest...
# 1850  observed the Baron, dryly, and at that instant...
# 1837  Secondary Sexual Characters Variable.- I think...
# 1831  Nothing there is motionless-        Nothing sa...
# ...                                                 ...
# 170             *What we now call the pulmonary artery.
# 1713  And yet you asserted that you could not concei...
# 1955  [297]  But what is like to  thy Word, our Lord...
# 101   CHAPTER 5    How magnanimity is consistent wit...
# 1660                                           Himself.
#
#                                                   4      \
# 1838  "Did not my great-granduncle, Peter Goldthwait...
# 1895  We came at length to the foot of the descent, ...
# 1850  For even as thou entreatedst me generously, wi...
# 1837  Drift timber is thrown up on most islands, eve...
# 1831  There open fanes and gaping graves       Yawn ...
# ...                                                 ...
# 170                        For this simple vessel [i.e.
# 1713  It cannot be denied that we perceive such cert...
# 1955                              CHAPTER VII       11.
# 101             for having acted conformably to nature?
# 1660  Nature sustains our feeble reason and prevents...
#
#                                                   5      \
# 1838  What a host of gloomy recollections will ever ...
# 1895                 and look to it what thou wilt do!"
# 1850                                        LA BRUYERE.
# 1837  LARYNX, The upper part of the windpipe opening...
# 1831                                        -THE END- .
# ...                                                 ...
# 170                                        the tissues.
# 1713  The colours, therefore, by it perceived are mo...
# 1955                                              Prov.
# 101   For philosophers say we allow none to be free ...
# 1660           Miracle does not always signify miracle.
#
#                                                   6      \
# 1838  The latter article of dress was of great impor...
# 1895                               ``Gods and fiends!''
# 1850  Thus, in less time than I have taken to tell i...
# 1837  This line of argument seems to have had great ...
# 1831  Ah, by no wind those clouds are driven        ...
# ...                                                 ...
# 170   For I see that the Erasistrateans are at varia...
# 1713  You may draw as many absurd consequences as yo...
# 1955  He "burns" with grief, for the things he has l...
# 101   Observe, this is the beginning of philosophy, ...
# 1660  The eternity of things in itself or in God mus...
#
#                                                   7      \
# 1838  "There is no use in rubbing it, Tabitha," said...
# 1895  Is not that the place where       an object up...
# 1850  In looking about, I discovered the interesting...
# 1837  In considering transitions of organs, it is so...
# 1831  can it be right-       This window open to the...
# ...                                                 ...
# 170   I think, then, it has been proved to the satis...
# 1713  I am not for changing things into ideas, but r...
# 1955  Now, surely, those who live in gross wickednes...
# 101   Wretch, are you so blind, and don't you see th...
# 1660  That which the prophets have said was to come ...
#
#                                                   8      \
# 1838  "And good cause have we to remember him," quot...
# 1895  Sometimes he inclined to believing them all he...
# 1850  And Kamar al-Akmar and his wife Shams al-Nahar...
# 1837  Almost every year, one or two land-birds are b...
# 1831  On desperate seas long wont to roam,          ...
# ...                                                 ...
# 170   And after the muscles, pass to the physical or...
# 1713  All which makes the case of <Matter> widely di...
# 1955  But  what hope he cherished, what struggles he...
# 101   To live secure, to be happy, to do everything ...
# 1660                It is making heavy the hand of God.
#
#                                                   9      ... 56118 56119  \
# 1838  You are avenged- they are all avenged- Nature ...  ...  None  None
# 1895                Sometimes he interjected anecdotes.  ...  None  None
# 1850  We mean the abrupt employment of a direct pron...  ...  None  None
# 1837  cried Colonel Killigrew, whose eyes had been f...  ...  None  None
# 1831  on yon drear and rigid bier low lies thy love,...  ...  None  None
# ...                                                 ...  ...   ...   ...
# 170   Has Erasistratus, then, not read the book, "On...  ...  None  None
# 1713       And what is conceived is surely in the mind?  ...  None  None
# 1955  Oh, if thou wouldst slay them with thy  two-ed...  ...  None  None
# 101                    And does not Antisthenes say so?  ...  None  None
# 1660                                               355.  ...  None  None
#
#      56120 56121 56122 56123 56124 56125 56126 56127
# 1838  None  None  None  None  None  None  None  None
# 1895  None  None  None  None  None  None  None  None
# 1850  None  None  None  None  None  None  None  None
# 1837  None  None  None  None  None  None  None  None
# 1831  None  None  None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 170   None  None  None  None  None  None  None  None
# 1713  None  None  None  None  None  None  None  None
# 1955  None  None  None  None  None  None  None  None
# 101   None  None  None  None  None  None  None  None
# 1660  None  None  None  None  None  None  None  None
#
# [189 rows x 56128 columns]
